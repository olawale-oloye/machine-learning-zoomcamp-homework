# %%
# import libraries 
import pandas as pd 
import numpy as np

# %%
pd.__version__
# Out:
# '2.3.1'

# %%
# ingest dataset 
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')

# %%
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# ...

# %%
df.shape
# Out:
# (9704, 11)

# %%
df['fuel_type'].nunique()
# Out:
# 2

# %%
df['fuel_type']
# Out:
# 0       Gasoline
# 1       Gasoline
# 2       Gasoline
# 3         Diesel
# 4       Gasoline
#           ...
# 9699      Diesel
# 9700    Gasoline
# 9701      Diesel
# 9702      Diesel
# 9703      Diesel
# Name: fuel_type, Length: 9704, dtype: object

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df['origin']
# Out:
# 0       Europe
# 1          USA
# 2       Europe
# 3          USA
# 4       Europe
#          ...
# 9699    Europe
# 9700       USA
# 9701       USA
# 9702       USA
# 9703      Asia
# Name: origin, Length: 9704, dtype: object

# %%
df['fuel_efficiency_mpg'].max()
# Out:
# np.float64(25.96722204888372)

# %%
df_asia = df[df['origin'] == 'Asia']['fuel_efficiency_mpg']
df_asia
# Out:
# 8       16.823554
# 12      16.175820
# 14      11.871091
# 20      18.889083
# 21      16.077730
#           ...
# 9688    11.054830
# 9692    11.711653
# 9693    17.202782
# 9698    13.933716
# 9703    14.884467
# Name: fuel_efficiency_mpg, Length: 3247, dtype: float64

# %%
df_asia = df.loc[df['origin']== 'Asia', 'fuel_efficiency_mpg']
df_asia
# Out:
# 8       16.823554
# 12      16.175820
# 14      11.871091
# 20      18.889083
# 21      16.077730
#           ...
# 9688    11.054830
# 9692    11.711653
# 9693    17.202782
# 9698    13.933716
# 9703    14.884467
# Name: fuel_efficiency_mpg, Length: 3247, dtype: float64

# %%
df.loc[df['origin']== 'Asia', 'fuel_efficiency_mpg'].max()
# Out:
# np.float64(23.759122836520497)

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
df['horsepower'].describe()
# Out:
# count    8996.000000
# mean      149.657292
# std        29.879555
# min        37.000000
# 25%       130.000000
# 50%       149.000000
# 75%       170.000000
# max       271.000000
# Name: horsepower, dtype: float64

# %%
df['horsepower'].median()
# Out:
# np.float64(149.0)

# %%
mode = df['horsepower'].mode()[0]
mode
# Out:
# np.float64(152.0)

# %%
df['horsepower'].isnull().sum()
# Out:
# np.int64(708)

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df['horsepower'].fillna(mode, inplace=True)

# %%
df['horsepower'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['horsepower'].median()
# Out:
# np.float64(152.0)

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower               0
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0       152.0     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
df_asia_cars = df[df['origin']== 'Asia']
df_asia_cars
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 8                     250            1.0       174.0     2714.219310
# 12                    320            5.0       145.0     2783.868974
# 14                    200            6.0       160.0     3582.687368
# 20                    150            3.0       197.0     2231.808142
# 21                    160            4.0       133.0     2659.431451
# ...                   ...            ...         ...             ...
# 9688                  260            4.0       152.0     3948.404625
# 9692                  180            3.0       188.0     3680.341381
# 9693                  280            2.0       148.0     2545.070139
# 9698                  180            1.0       131.0     3107.427820
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year origin fuel_type         drivetrain  num_doors  \
# ...

# %%
df[df['origin']== 'Asia']['vehicle_weight'].sum()
# Out:
# np.float64(9761430.865104277)

# %%
df[df['origin']== 'Asia'][['vehicle_weight', 'model_year']].sum()
# Out:
# vehicle_weight    9.761431e+06
# model_year        6.531306e+06
# dtype: float64

# %%
df.head(7).sum()
# Out:
# engine_displacement                                                 1330
# num_cylinders                                                       23.0
# horsepower                                                         905.0
# vehicle_weight                                              21136.827355
# acceleration                                                       122.1
# model_year                                                         14066
# origin                                 EuropeUSAEuropeUSAEuropeEuropeUSA
# fuel_type              GasolineGasolineGasolineDieselGasolineGasoline...
# drivetrain             All-wheel driveFront-wheel driveFront-wheel dr...
# num_doors                                                            4.0
# fuel_efficiency_mpg                                           101.049623
# dtype: object

# %%
df_asia_cars.head(7).sum()
# Out:
# engine_displacement                                                 1420
# num_cylinders                                                       26.0
# horsepower                                                        1116.0
# vehicle_weight                                              20578.236816
# acceleration                                                        76.3
# model_year                                                         14093
# origin                                      AsiaAsiaAsiaAsiaAsiaAsiaAsia
# fuel_type               DieselDieselDieselGasolineGasolineDieselGasoline
# drivetrain             Front-wheel driveAll-wheel driveAll-wheel driv...
# num_doors                                                            1.0
# fuel_efficiency_mpg                                           106.836789
# dtype: object

# %%
X = np.array(df[df['origin']== 'Asia'])
X
# Out:
# array([[250, 1.0, 174.0, ..., 'Front-wheel drive', -1.0,
#         16.823553726916543],
#        [320, 5.0, 145.0, ..., 'All-wheel drive', 1.0, 16.17581958009284],
#        [200, 6.0, 160.0, ..., 'All-wheel drive', 0.0, 11.871091010445811],
#        ...,
#        [280, 2.0, 148.0, ..., 'All-wheel drive', 0.0, 17.202782219342595],
#        [180, 1.0, 131.0, ..., 'Front-wheel drive', -2.0,
#         13.93371607794469],
#        [270, 3.0, 140.0, ..., 'All-wheel drive', -1.0,
#         14.884467402842692]], shape=(3247, 11), dtype=object)

# %%
n = np.random.randint(low=1, high=100, size=(5,5))
n
# Out:
# array([[86,  7, 35, 73, 57],
#        [ 3, 85, 97, 87,  6],
#        [49, 85, 26, 98, 44],
#        [71, 97,  6, 48,  1],
#        [18, 99, 65, 87, 82]])

# %%
# n = np.arange()
# n

# %%
data = [
    ['Nissan', 'Stanza', 1991, 138, 4, 'MANUAL', 'sedan', 2000],
    ['Hyundai', 'Sonata', 2017, None, 4, 'AUTOMATIC', 'Sedan', 27150],
    ['Lotus', 'Elise', 2010, 218, 4, 'MANUAL', 'convertible', 54990],
    ['GMC', 'Acadia',  2017, 194, 4, 'AUTOMATIC', '4dr SUV', 34450],
    ['Nissan', 'Frontier', 2017, 261, 6, 'MANUAL', 'Pickup', 32340],
]
 
col = [
    'Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders',
    'Transmission Type', 'Vehicle_Style', 'MSRP'
]
 
pd.DataFrame(data)
# Out:
#          0         1     2      3  4          5            6      7
# 0   Nissan    Stanza  1991  138.0  4     MANUAL        sedan   2000
# 1  Hyundai    Sonata  2017    NaN  4  AUTOMATIC        Sedan  27150
# 2    Lotus     Elise  2010  218.0  4     MANUAL  convertible  54990
# 3      GMC    Acadia  2017  194.0  4  AUTOMATIC      4dr SUV  34450
# 4   Nissan  Frontier  2017  261.0  6     MANUAL       Pickup  32340

# %%
df = pd.DataFrame(data, columns=col)

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.Make
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df['Make']
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df.index = [1,2,3,4,5]

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1   Nissan    Stanza  1991      138.0                 4            MANUAL
# 2  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 3    Lotus     Elise  2010      218.0                 4            MANUAL
# 4      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 5   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 1         sedan   2000
# 2         Sedan  27150
# 3   convertible  54990
# 4       4dr SUV  34450
# 5        Pickup  32340

# %%
df.loc[1]
# Out:
# Make                 Nissan
# Model                Stanza
# Year                   1991
# Engine HP             138.0
# Engine Cylinders          4
# Transmission Type    MANUAL
# Vehicle_Style         sedan
# MSRP                   2000
# Name: 1, dtype: object

# %%
df.loc[[1,2]]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1   Nissan  Stanza  1991      138.0                 4            MANUAL
# 2  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# 1         sedan   2000
# 2         Sedan  27150

# %%
df[['Make', 'Model']]
# Out:
#       Make     Model
# 1   Nissan    Stanza
# 2  Hyundai    Sonata
# 3    Lotus     Elise
# 4      GMC    Acadia
# 5   Nissan  Frontier

# %%
df.iloc[1]
# Out:
# Make                   Hyundai
# Model                   Sonata
# Year                      2017
# Engine HP                  NaN
# Engine Cylinders             4
# Transmission Type    AUTOMATIC
# Vehicle_Style            Sedan
# MSRP                     27150
# Name: 2, dtype: object

# %%
df.iloc[[1, 2]]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 2  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# 3    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# 2         Sedan  27150
# 3   convertible  54990

# %%
df.index = ['a', 'b', 'c', 'd', 'e']

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         Sedan  27150
# c   convertible  54990
# d       4dr SUV  34450
# e        Pickup  32340

# %%
df.loc['a']
# Out:
# Make                 Nissan
# Model                Stanza
# Year                   1991
# Engine HP             138.0
# Engine Cylinders          4
# Transmission Type    MANUAL
# Vehicle_Style         sedan
# MSRP                   2000
# Name: a, dtype: object

# %%
df.loc[['b', 'a']]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# b  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# a   Nissan  Stanza  1991      138.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# b         Sedan  27150
# a         sedan   2000

# %%
df.iloc[[2, 1]]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# c    Lotus   Elise  2010      218.0                 4            MANUAL
# b  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# c   convertible  54990
# b         Sedan  27150

# %%
df.reset_index()
# Out:
#   index     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0     a   Nissan    Stanza  1991      138.0                 4
# 1     b  Hyundai    Sonata  2017        NaN                 4
# 2     c    Lotus     Elise  2010      218.0                 4
# 3     d      GMC    Acadia  2017      194.0                 4
# 4     e   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         Sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr SUV  34450
# 4            MANUAL        Pickup  32340

# %%
df.reset_index(drop = True)
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         Sedan  27150
# c   convertible  54990
# d       4dr SUV  34450
# e        Pickup  32340

# %%
df = df.reset_index(drop = True)
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.Year >= 2015
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Year, dtype: bool

# %%
df[df.Year >= 2015]
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df[df['Year'] >= 2015]
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df[(df['Make'] == 'Nissan') & (df['Year'] >= 2015)]
# Out:
#      Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 4  Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 4        Pickup  32340

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df['Vehicle_Style']
# Out:
# 0          sedan
# 1          Sedan
# 2    convertible
# 3        4dr SUV
# 4         Pickup
# Name: Vehicle_Style, dtype: object

# %%
df['Vehicle_Style'] = df['Vehicle_Style'].str.capitalize()
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         Sedan   2000
# 1         Sedan  27150
# 2   Convertible  54990
# 3       4dr suv  34450
# 4        Pickup  32340

# %%
df['Vehicle_Style'] = df['Vehicle_Style'].str.replace(' ', '_')

df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         Sedan   2000
# 1         Sedan  27150
# 2   Convertible  54990
# 3       4dr_suv  34450
# 4        Pickup  32340

# %%
df['Vehicle_Style'] = df['Vehicle_Style'].str.lower().str.replace('_', "=")
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         sedan  27150
# 2   convertible  54990
# 3       4dr=suv  34450
# 4        pickup  32340

# %%
df['Vehicle_Style'] = df['Vehicle_Style'].str.capitalize().str.replace('=', "_")
df['Transmission Type'] = df['Transmission Type'].str.capitalize()
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            Manual
# 1  Hyundai    Sonata  2017        NaN                 4         Automatic
# 2    Lotus     Elise  2010      218.0                 4            Manual
# 3      GMC    Acadia  2017      194.0                 4         Automatic
# 4   Nissan  Frontier  2017      261.0                 6            Manual
#
#   Vehicle_Style   MSRP
# 0         Sedan   2000
# 1         Sedan  27150
# 2   Convertible  54990
# 3       4dr_suv  34450
# 4        Pickup  32340

# %%
df['Engine HP'] = df['Engine HP'].fillna(0)
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            Manual
# 1  Hyundai    Sonata  2017        0.0                 4         Automatic
# 2    Lotus     Elise  2010      218.0                 4            Manual
# 3      GMC    Acadia  2017      194.0                 4         Automatic
# 4   Nissan  Frontier  2017      261.0                 6            Manual
#
#   Vehicle_Style   MSRP
# 0         Sedan   2000
# 1         Sedan  27150
# 2   Convertible  54990
# 3       4dr_suv  34450
# 4        Pickup  32340

# %%
df.MSRP.min()
# Out:
# np.int64(2000)

# %%
df.MSRP.max()
# Out:
# np.int64(54990)

# %%
df.MSRP.std()
# Out:
# np.float64(18985.044903818372)

# %%
df.MSRP.count()
# Out:
# np.int64(5)

# %%
df.MSRP.mean()
# Out:
# np.float64(30186.0)

# %%
df.MSRP.describe()
# Out:
# count        5.000000
# mean     30186.000000
# std      18985.044904
# min       2000.000000
# 25%      27150.000000
# 50%      32340.000000
# 75%      34450.000000
# max      54990.000000
# Name: MSRP, dtype: float64

# %%
df.Make.nunique()
# Out:
# 4

# %%
df.nunique()
# Out:
# Make                 4
# Model                5
# Year                 3
# Engine HP            5
# Engine Cylinders     2
# Transmission Type    2
# Vehicle_Style        4
# MSRP                 5
# dtype: int64

# %%
df.isnull()
# Out:
#     Make  Model   Year  Engine HP  Engine Cylinders  Transmission Type  \
# 0  False  False  False      False             False              False
# 1  False  False  False      False             False              False
# 2  False  False  False      False             False              False
# 3  False  False  False      False             False              False
# 4  False  False  False      False             False              False
#
#    Vehicle_Style   MSRP
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Vehicle_Style        0
# MSRP                 0
# dtype: int64

# %% [markdown]
# # Grouping
#
# ```
# SELECT
#     transmission_type,
#     AVG(MSRP)
# FROM
#     cars
# GROUP BY
#     transmission_type
#
# ```

# %%
df.groupby('Transmission Type').mean('MSRP')
# Out:
#                      Year   Engine HP  Engine Cylinders          MSRP
# Transmission Type
# Automatic          2017.0   97.000000          4.000000  30800.000000
# Manual             2006.0  205.666667          4.666667  29776.666667

# %%
df.to_dict(orient='records')
# Out:
# [{'Make': 'Nissan',
#   'Model': 'Stanza',
#   'Year': 1991,
#   'Engine HP': 138.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'Manual',
#   'Vehicle_Style': 'Sedan',
#   'MSRP': 2000},
#  {'Make': 'Hyundai',
#   'Model': 'Sonata',
#   'Year': 2017,
#   'Engine HP': 0.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'Automatic',
#   'Vehicle_Style': 'Sedan',
#   'MSRP': 27150},
#  {'Make': 'Lotus',
#   'Model': 'Elise',
#   'Year': 2010,
#   'Engine HP': 218.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'Manual',
#   'Vehicle_Style': 'Convertible',
#   'MSRP': 54990},
#  {'Make': 'GMC',
#   'Model': 'Acadia',
#   'Year': 2017,
#   'Engine HP': 194.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'Automatic',
#   'Vehicle_Style': '4dr_suv',
#   'MSRP': 34450},
#  {'Make': 'Nissan',
#   'Model': 'Frontier',
#   'Year': 2017,
#   'Engine HP': 261.0,
#   'Engine Cylinders': 6,
#   'Transmission Type': 'Manual',
#   'Vehicle_Style': 'Pickup',
# ...

# %%
df.groupby('Transmission Type')['MSRP'].mean('MSRP')
# Out:
# Transmission Type
# Automatic    30800.000000
# Manual       29776.666667
# Name: MSRP, dtype: float64
